# %%
import requests

url = "https://api-voice.botnoi.ai/openapi/v1/generate_audio"

headers = {
    "Content-Type": "application/json",
    "botnoi-token": "MKxsMU7u7hC6iUBJzKLbraO1Cb21D6AM"
}

payload = {
    "text": "สวัสดีครับ",
    "speaker": "1",
    "volume": 1,
    "speed": 1,
    "type_media": "mp3",
    "save_file": "true",
    "language": "th",
    "page": "user"
}

response = requests.post(url, json=payload, headers=headers)
print(response.text)
# Out:
# {"text":"สวัสดีครับ","audio_url":"https://botnoi-dictionary.s3.amazonaws.com/63a422a392437c99311cfae5a90a0e4864fcaca0974f27d8b48b764ff931e951_01132026022425500793.mp3","point":1990,"user_monthly_point":0}

# %%
# !nslookup api.botnoi.ai
# Out:
# Server:		10.1.101.2
# Address:	10.1.101.2#53
#
# ** server can't find api.botnoi.ai: NXDOMAIN
